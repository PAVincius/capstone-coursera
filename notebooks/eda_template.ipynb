# %% [markdown]
# # EDA Command Center
#
# Analise exploratória de dados para comparação de modelos.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from src.ingestion import ingest_data

# %matplotlib inline

# %% [markdown]
# ## 1. Carregamento de Dados
# Utilizando o script de ingestão do projeto.

# %%
data_path = os.path.join("..", "data", "*.csv")
df = ingest_data(data_path)
df.head()

# %% [markdown]
# ## 2. Visualizações (EDA)
# ### Gráficos de Dispersão e Histogramas

# %%
# Exemplo: sns.pairplot(df)

# %% [markdown]
# ### Matriz de Correlação

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## 3. Comparação de Modelos
# Comparando Baseline (Média/Regressão) com SOTA (RandomForest/XGBoost).

# %%
# Plotar erros
models = ['Baseline', 'RandomForest']
errors = [0.55, 0.23]
plt.bar(models, errors)
plt.ylabel('MSE')
plt.title('Comparação de Performance')
plt.show()
